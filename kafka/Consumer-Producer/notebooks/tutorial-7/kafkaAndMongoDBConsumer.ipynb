# %%
from kafka import KafkaConsumer
from pymongo import MongoClient
from json import loads

topic_name = 'numtest_LeNguyenHoangPhuc'
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=['kafka:9092'],
    auto_offset_reset='earliest',
    enable_auto_commit=True,
    group_id='my-group',
    value_deserializer=lambda x: loads(x.decode('utf-8'))
)

client = MongoClient('mongodb://phuchoang2005:12345678@mongodb:27017/')
collection = client.numtest_LeNguyenHoangPhuc.numtest_LeNguyenHoangPhuc
try:
    for message in consumer:
        message = message.value
        collection.insert_one(message)
        print('{} added to {}'.format(message, collection))
except KeyboardInterrupt:
    print("break")
finally:
    consumer.close()
print("Live ended")
# Out:
# {'number': 16, '_id': ObjectId('68f26ef757978959d908ce3d')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 17, '_id': ObjectId('68f26ef757978959d908ce3e')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 0, '_id': ObjectId('68f26ef757978959d908ce3f')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 1, '_id': ObjectId('68f26ef757978959d908ce40')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 2, '_id': ObjectId('68f26ef757978959d908ce41')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 3, '_id': ObjectId('68f26ef757978959d908ce42')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 4, '_id': ObjectId('68f26ef757978959d908ce43')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 5, '_id': ObjectId('68f26ef757978959d908ce44')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 6, '_id': ObjectId('68f26ef757978959d908ce45')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 7, '_id': ObjectId('68f26ef757978959d908ce46')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 8, '_id': ObjectId('68f26ef757978959d908ce47')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 9, '_id': ObjectId('68f26ef757978959d908ce48')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 10, '_id': ObjectId('68f26ef757978959d908ce49')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 11, '_id': ObjectId('68f26ef757978959d908ce4a')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 12, '_id': ObjectId('68f26ef757978959d908ce4b')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 13, '_id': ObjectId('68f26ef757978959d908ce4c')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 14, '_id': ObjectId('68f26ef757978959d908ce4d')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 15, '_id': ObjectId('68f26ef757978959d908ce4e')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 16, '_id': ObjectId('68f26ef757978959d908ce4f')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 17, '_id': ObjectId('68f26ef757978959d908ce50')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 18, '_id': ObjectId('68f26ef757978959d908ce51')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 19, '_id': ObjectId('68f26ef757978959d908ce52')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 20, '_id': ObjectId('68f26ef757978959d908ce53')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 21, '_id': ObjectId('68f26ef757978959d908ce54')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 22, '_id': ObjectId('68f26ef757978959d908ce55')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 23, '_id': ObjectId('68f26ef757978959d908ce56')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 24, '_id': ObjectId('68f26ef757978959d908ce57')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 25, '_id': ObjectId('68f26ef757978959d908ce58')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 26, '_id': ObjectId('68f26ef757978959d908ce59')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 27, '_id': ObjectId('68f26ef757978959d908ce5a')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 28, '_id': ObjectId('68f26ef757978959d908ce5b')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 29, '_id': ObjectId('68f26ef757978959d908ce5c')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 30, '_id': ObjectId('68f26ef757978959d908ce5d')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 31, '_id': ObjectId('68f26ef757978959d908ce5e')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 32, '_id': ObjectId('68f26ef757978959d908ce5f')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 33, '_id': ObjectId('68f26ef757978959d908ce60')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 34, '_id': ObjectId('68f26ef757978959d908ce61')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 35, '_id': ObjectId('68f26ef757978959d908ce62')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 36, '_id': ObjectId('68f26ef757978959d908ce63')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 37, '_id': ObjectId('68f26ef757978959d908ce64')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 38, '_id': ObjectId('68f26ef757978959d908ce65')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 39, '_id': ObjectId('68f26ef757978959d908ce66')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 40, '_id': ObjectId('68f26ef757978959d908ce67')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 41, '_id': ObjectId('68f26ef757978959d908ce68')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 42, '_id': ObjectId('68f26ef757978959d908ce69')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 43, '_id': ObjectId('68f26ef757978959d908ce6a')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 44, '_id': ObjectId('68f26ef757978959d908ce6b')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 45, '_id': ObjectId('68f26ef757978959d908ce6c')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 46, '_id': ObjectId('68f26ef757978959d908ce6d')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 47, '_id': ObjectId('68f26efc57978959d908ce6e')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 48, '_id': ObjectId('68f26f0157978959d908ce6f')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 49, '_id': ObjectId('68f26f0657978959d908ce70')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 50, '_id': ObjectId('68f26f0b57978959d908ce71')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 51, '_id': ObjectId('68f26f1057978959d908ce72')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 52, '_id': ObjectId('68f26f1557978959d908ce73')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 53, '_id': ObjectId('68f26f1a57978959d908ce74')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 54, '_id': ObjectId('68f26f1f57978959d908ce75')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 55, '_id': ObjectId('68f26f2457978959d908ce76')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 56, '_id': ObjectId('68f26f2957978959d908ce77')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 57, '_id': ObjectId('68f26f2e57978959d908ce78')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 58, '_id': ObjectId('68f26f3357978959d908ce79')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 59, '_id': ObjectId('68f26f3857978959d908ce7a')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 60, '_id': ObjectId('68f26f3d57978959d908ce7b')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 61, '_id': ObjectId('68f26f4257978959d908ce7c')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 62, '_id': ObjectId('68f26f4757978959d908ce7d')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 63, '_id': ObjectId('68f26f4c57978959d908ce7e')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 64, '_id': ObjectId('68f26f5157978959d908ce7f')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 65, '_id': ObjectId('68f26f5657978959d908ce80')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 66, '_id': ObjectId('68f26f5b57978959d908ce81')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 67, '_id': ObjectId('68f26f6057978959d908ce82')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 68, '_id': ObjectId('68f26f6557978959d908ce83')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# {'number': 69, '_id': ObjectId('68f26f6a57978959d908ce84')} added to Collection(Database(MongoClient(host=['mongodb:27017'], document_class=dict, tz_aware=False, connect=True), 'numtest_LeNguyenHoangPhuc'), 'numtest_LeNguyenHoangPhuc')
# break
# Live ended
