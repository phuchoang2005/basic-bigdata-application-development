# %%
import json
import random
import time
from datetime import datetime
import numpy as np
import logging
import socket
from confluent_kafka import Producer, Consumer
import random
from joblib import dump
import numpy as np
from sklearn.ensemble import IsolationForest

# %%
DELAY = 2
OUTLIERS_GENERATION_PROBABILITY = 0.2
KAFKA_BROKER = "kafka:9092"
TRANSACTIONS_TOPIC = "transactions"

# %%
rng = np.random.RandomState(42)

# Generate train data
X = 0.3 * rng.randn(500, 2)
X_train = np.r_[X + 2, X - 2]
X_train = np.round(X_train, 3)

# fit the model
clf = IsolationForest(n_estimators=50, max_samples=500, random_state=rng, contamination=0.01)
clf.fit(X_train)

dump(clf, './isolation_forest.joblib')
# Out:
# ['./isolation_forest.joblib']

# %% [markdown]
# Producer

# %%
def create_producer():
    try:
        producer = Producer({"bootstrap.servers": KAFKA_BROKER,
                             "client.id": socket.gethostname(),
                             "enable.idempotence": True,  # EOS processing
                             "compression.type": "lz4",
                             "batch.size": 64000,
                             "linger.ms": 10,
                             "acks": "all",  # Wait for the leader and all ISR to send response back
                             "retries": 5,
                             "delivery.timeout.ms": 1000})  # Total time to make retries
    except Exception as e:
        logging.exception("Couldn't create the producer")
        producer = None
    return producer


def create_consumer(topic, group_id):
    try:
        consumer = Consumer({"bootstrap.servers": KAFKA_BROKER,
                             "group.id": group_id,
                             "client.id": socket.gethostname(),
                             "isolation.level": "read_committed",
                             "default.topic.config": {"auto.offset.reset": "latest", # Only consume new messages
                                                      "enable.auto.commit": False}
                             })

        consumer.subscribe([topic])
    except Exception as e:
        logging.exception("Couldn't create the consumer")
        consumer = None

    return consumer

# %%
_id = 0
producer = create_producer()

if producer is not None:
    try:
        while True:
            print("This code is printed by Le Nguyen Hoang Phuc - 23521198")
            # Generate some abnormal observations
            if random.random() <= OUTLIERS_GENERATION_PROBABILITY:
                X_test = np.random.uniform(low=-4, high=4, size=(1, 2))
            else:
                X = 0.3 * np.random.randn(1, 2)
                X_test = (X + np.random.choice(a=[2, -2], size=1, p=[0.5, 0.5]))

            X_test = np.round(X_test, 3).tolist()

            current_time = datetime.utcnow().isoformat()

            record = {"id": _id, "data": X_test, "current_time": current_time}
            record = json.dumps(record).encode("utf-8")
            print('produce message')
            print(record)

            producer.produce(topic=TRANSACTIONS_TOPIC,
                            value=record)
            producer.flush()
            _id += 1
            time.sleep(DELAY)
    except KeyboardInterrupt: print("Stopped")
    finally:
        producer.flush()
# Out:
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 0, "data": [[-1.996, -1.442]], "current_time": "2025-11-25T08:53:13.019329"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 1, "data": [[1.394, 1.879]], "current_time": "2025-11-25T08:53:16.024602"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 2, "data": [[-2.026, -1.978]], "current_time": "2025-11-25T08:53:18.187146"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 3, "data": [[-0.725, -2.715]], "current_time": "2025-11-25T08:53:20.192412"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 4, "data": [[-3.215, 3.688]], "current_time": "2025-11-25T08:53:22.197033"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 5, "data": [[-0.378, -3.177]], "current_time": "2025-11-25T08:53:24.200144"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 6, "data": [[1.842, 2.14]], "current_time": "2025-11-25T08:53:26.203162"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 7, "data": [[2.209, 2.044]], "current_time": "2025-11-25T08:53:28.206759"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 8, "data": [[1.863, 1.695]], "current_time": "2025-11-25T08:53:30.210111"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 9, "data": [[1.513, 1.996]], "current_time": "2025-11-25T08:53:32.212746"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 10, "data": [[0.241, 2.221]], "current_time": "2025-11-25T08:53:34.217024"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 11, "data": [[-2.059, -2.035]], "current_time": "2025-11-25T08:53:36.223102"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 12, "data": [[-2.062, -2.141]], "current_time": "2025-11-25T08:53:38.226209"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 13, "data": [[0.123, -3.173]], "current_time": "2025-11-25T08:53:40.231578"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 14, "data": [[-1.912, -1.732]], "current_time": "2025-11-25T08:53:42.234394"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 15, "data": [[2.026, 2.203]], "current_time": "2025-11-25T08:53:44.239416"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 16, "data": [[2.092, 2.105]], "current_time": "2025-11-25T08:53:46.241927"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 17, "data": [[-1.35, -2.396]], "current_time": "2025-11-25T08:53:48.245577"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 18, "data": [[-1.774, -1.653]], "current_time": "2025-11-25T08:53:50.249927"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 19, "data": [[1.857, 2.298]], "current_time": "2025-11-25T08:53:52.253554"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 20, "data": [[3.317, -1.734]], "current_time": "2025-11-25T08:53:54.257839"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 21, "data": [[1.859, 1.502]], "current_time": "2025-11-25T08:53:56.262438"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 22, "data": [[-2.264, -2.044]], "current_time": "2025-11-25T08:53:58.266207"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 23, "data": [[1.622, 2.332]], "current_time": "2025-11-25T08:54:00.270764"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 24, "data": [[-2.727, -1.922]], "current_time": "2025-11-25T08:54:02.274020"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 25, "data": [[2.501, 1.87]], "current_time": "2025-11-25T08:54:04.277773"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 26, "data": [[-1.353, -1.796]], "current_time": "2025-11-25T08:54:06.281682"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 27, "data": [[-2.476, -1.951]], "current_time": "2025-11-25T08:54:08.285957"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 28, "data": [[-2.164, -1.538]], "current_time": "2025-11-25T08:54:10.288854"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 29, "data": [[1.581, 1.964]], "current_time": "2025-11-25T08:54:12.296926"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 30, "data": [[-2.153, -2.168]], "current_time": "2025-11-25T08:54:14.303058"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 31, "data": [[-1.787, -1.778]], "current_time": "2025-11-25T08:54:16.311361"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 32, "data": [[1.827, 1.722]], "current_time": "2025-11-25T08:54:18.314680"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 33, "data": [[1.876, 2.075]], "current_time": "2025-11-25T08:54:20.366283"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 34, "data": [[1.935, 1.377]], "current_time": "2025-11-25T08:54:22.369162"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 35, "data": [[1.983, 1.836]], "current_time": "2025-11-25T08:54:24.373075"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 36, "data": [[-2.505, -1.868]], "current_time": "2025-11-25T08:54:26.376993"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 37, "data": [[-2.339, -1.921]], "current_time": "2025-11-25T08:54:28.379724"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 38, "data": [[-2.263, -1.64]], "current_time": "2025-11-25T08:54:30.382741"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 39, "data": [[-2.026, -2.022]], "current_time": "2025-11-25T08:54:32.387394"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 40, "data": [[1.856, 2.363]], "current_time": "2025-11-25T08:54:34.391971"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 41, "data": [[-2.0, -1.742]], "current_time": "2025-11-25T08:54:36.394600"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 42, "data": [[-1.594, -2.1]], "current_time": "2025-11-25T08:54:38.397012"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 43, "data": [[-1.532, 1.505]], "current_time": "2025-11-25T08:54:40.399177"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 44, "data": [[-1.768, -2.491]], "current_time": "2025-11-25T08:54:42.403041"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 45, "data": [[0.985, -1.499]], "current_time": "2025-11-25T08:54:44.406817"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 46, "data": [[1.695, 1.751]], "current_time": "2025-11-25T08:54:46.409102"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 47, "data": [[-1.759, -1.725]], "current_time": "2025-11-25T08:54:48.410881"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 48, "data": [[2.022, 2.063]], "current_time": "2025-11-25T08:54:50.413637"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 49, "data": [[-3.848, -3.488]], "current_time": "2025-11-25T08:54:52.415483"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 50, "data": [[2.095, 1.992]], "current_time": "2025-11-25T08:54:54.418705"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 51, "data": [[3.599, -0.291]], "current_time": "2025-11-25T08:54:56.420695"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 52, "data": [[-2.138, -2.08]], "current_time": "2025-11-25T08:54:58.424364"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 53, "data": [[-1.923, -2.31]], "current_time": "2025-11-25T08:55:00.430065"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 54, "data": [[-1.081, 3.616]], "current_time": "2025-11-25T08:55:02.432596"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 55, "data": [[-2.167, -2.143]], "current_time": "2025-11-25T08:55:04.436355"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 56, "data": [[3.212, 3.084]], "current_time": "2025-11-25T08:55:06.442083"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 57, "data": [[2.057, 1.728]], "current_time": "2025-11-25T08:55:08.444934"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 58, "data": [[-2.071, -1.647]], "current_time": "2025-11-25T08:55:10.448175"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 59, "data": [[-2.154, -2.118]], "current_time": "2025-11-25T08:55:12.451266"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 60, "data": [[1.998, 2.236]], "current_time": "2025-11-25T08:55:14.453367"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 61, "data": [[1.717, 2.055]], "current_time": "2025-11-25T08:55:16.457767"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 62, "data": [[-1.764, -1.592]], "current_time": "2025-11-25T08:55:18.462560"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 63, "data": [[1.562, 1.577]], "current_time": "2025-11-25T08:55:20.466282"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 64, "data": [[-2.232, -1.37]], "current_time": "2025-11-25T08:55:22.469251"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 65, "data": [[2.321, 2.635]], "current_time": "2025-11-25T08:55:24.471239"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 66, "data": [[1.437, 2.245]], "current_time": "2025-11-25T08:55:26.475927"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 67, "data": [[1.755, 2.385]], "current_time": "2025-11-25T08:55:28.482568"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 68, "data": [[2.118, 2.095]], "current_time": "2025-11-25T08:55:30.484484"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 69, "data": [[2.047, 1.835]], "current_time": "2025-11-25T08:55:32.487040"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 70, "data": [[1.621, 2.176]], "current_time": "2025-11-25T08:55:34.490944"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 71, "data": [[2.054, 2.016]], "current_time": "2025-11-25T08:55:36.494202"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 72, "data": [[1.303, 1.386]], "current_time": "2025-11-25T08:55:38.495941"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 73, "data": [[-1.709, -2.162]], "current_time": "2025-11-25T08:55:40.498718"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 74, "data": [[2.366, 1.869]], "current_time": "2025-11-25T08:55:42.501094"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 75, "data": [[-2.048, -1.964]], "current_time": "2025-11-25T08:55:44.503303"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 76, "data": [[1.948, 2.013]], "current_time": "2025-11-25T08:55:46.505214"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 77, "data": [[-2.35, -2.082]], "current_time": "2025-11-25T08:55:48.507133"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 78, "data": [[1.918, 2.126]], "current_time": "2025-11-25T08:55:50.509631"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 79, "data": [[0.657, -1.075]], "current_time": "2025-11-25T08:55:52.511798"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 80, "data": [[-1.846, -1.979]], "current_time": "2025-11-25T08:55:54.514790"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 81, "data": [[2.287, 2.135]], "current_time": "2025-11-25T08:55:56.518189"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 82, "data": [[1.652, 2.466]], "current_time": "2025-11-25T08:55:58.519911"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 83, "data": [[1.706, 1.855]], "current_time": "2025-11-25T08:56:00.526046"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 84, "data": [[-2.291, -2.258]], "current_time": "2025-11-25T08:56:02.528914"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 85, "data": [[-2.088, -1.531]], "current_time": "2025-11-25T08:56:04.532048"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 86, "data": [[-2.297, -2.172]], "current_time": "2025-11-25T08:56:06.535458"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 87, "data": [[2.053, 1.634]], "current_time": "2025-11-25T08:56:08.539641"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 88, "data": [[2.254, 1.715]], "current_time": "2025-11-25T08:56:10.542538"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 89, "data": [[1.843, 2.262]], "current_time": "2025-11-25T08:56:12.547739"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 90, "data": [[-2.423, -1.748]], "current_time": "2025-11-25T08:56:14.550275"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 91, "data": [[1.548, 1.657]], "current_time": "2025-11-25T08:56:16.553196"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 92, "data": [[-2.069, -2.259]], "current_time": "2025-11-25T08:56:18.556208"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 93, "data": [[-2.18, -2.092]], "current_time": "2025-11-25T08:56:20.561177"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 94, "data": [[0.141, -0.502]], "current_time": "2025-11-25T08:56:22.563518"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 95, "data": [[1.724, 2.234]], "current_time": "2025-11-25T08:56:24.567410"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 96, "data": [[1.937, 1.885]], "current_time": "2025-11-25T08:56:26.578851"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 97, "data": [[1.825, 2.011]], "current_time": "2025-11-25T08:56:28.583177"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 98, "data": [[-2.337, -2.331]], "current_time": "2025-11-25T08:56:30.587414"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 99, "data": [[2.337, 2.217]], "current_time": "2025-11-25T08:56:32.590110"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 100, "data": [[1.606, 1.793]], "current_time": "2025-11-25T08:56:34.592344"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 101, "data": [[-1.783, -1.784]], "current_time": "2025-11-25T08:56:36.596318"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 102, "data": [[-0.859, 2.124]], "current_time": "2025-11-25T08:56:38.601480"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 103, "data": [[-2.529, -1.46]], "current_time": "2025-11-25T08:56:40.603997"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 104, "data": [[-0.56, 1.085]], "current_time": "2025-11-25T08:56:42.606782"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 105, "data": [[1.726, 2.592]], "current_time": "2025-11-25T08:56:44.610455"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 106, "data": [[1.732, 1.626]], "current_time": "2025-11-25T08:56:46.613792"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 107, "data": [[-2.253, -2.327]], "current_time": "2025-11-25T08:56:48.616084"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 108, "data": [[-0.897, -3.704]], "current_time": "2025-11-25T08:56:50.620382"}'
# This code is printed by Le Nguyen Hoang Phuc - 23521198
# produce message
# b'{"id": 109, "data": [[1.649, 1.578]], "current_time": "2025-11-25T08:56:52.623549"}'
# Stopped
