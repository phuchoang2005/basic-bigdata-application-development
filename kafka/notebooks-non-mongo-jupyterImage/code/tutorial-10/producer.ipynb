# %%
import json
import random
import time
from datetime import datetime
import numpy as np
import logging
import socket
from confluent_kafka import Producer, Consumer
import random
from joblib import dump
import numpy as np
from sklearn.ensemble import IsolationForest

# %%
DELAY = 2
OUTLIERS_GENERATION_PROBABILITY = 0.2
KAFKA_BROKER = "kafka:9092"
TRANSACTIONS_TOPIC = "transactions"

# %%
rng = np.random.RandomState(42)

# Generate train data
X = 0.3 * rng.randn(500, 2)
X_train = np.r_[X + 2, X - 2]
X_train = np.round(X_train, 3)

# fit the model
clf = IsolationForest(n_estimators=50, max_samples=500, random_state=rng, contamination=0.01)
clf.fit(X_train)

dump(clf, './isolation_forest.joblib')
# Out:
# ['./isolation_forest.joblib']

# %% [markdown]
# Producer

# %%
def create_producer():
    try:
        producer = Producer({"bootstrap.servers": KAFKA_BROKER,
                             "client.id": socket.gethostname(),
                             "enable.idempotence": True,  # EOS processing
                             "compression.type": "lz4",
                             "batch.size": 64000,
                             "linger.ms": 10,
                             "acks": "all",  # Wait for the leader and all ISR to send response back
                             "retries": 5,
                             "delivery.timeout.ms": 1000})  # Total time to make retries
    except Exception as e:
        logging.exception("Couldn't create the producer")
        producer = None
    return producer


def create_consumer(topic, group_id):
    try:
        consumer = Consumer({"bootstrap.servers": KAFKA_BROKER,
                             "group.id": group_id,
                             "client.id": socket.gethostname(),
                             "isolation.level": "read_committed",
                             "default.topic.config": {"auto.offset.reset": "latest", # Only consume new messages
                                                      "enable.auto.commit": False}
                             })

        consumer.subscribe([topic])
    except Exception as e:
        logging.exception("Couldn't create the consumer")
        consumer = None

    return consumer

# %%
_id = 0
producer = create_producer()

if producer is not None:
    try:
        while True:
            # Generate some abnormal observations
            if random.random() <= OUTLIERS_GENERATION_PROBABILITY:
                X_test = np.random.uniform(low=-4, high=4, size=(1, 2))
            else:
                X = 0.3 * np.random.randn(1, 2)
                X_test = (X + np.random.choice(a=[2, -2], size=1, p=[0.5, 0.5]))

            X_test = np.round(X_test, 3).tolist()

            current_time = datetime.utcnow().isoformat()

            record = {"id": _id, "data": X_test, "current_time": current_time}
            record = json.dumps(record).encode("utf-8")
            print('produce message')
            print(record)

            producer.produce(topic=TRANSACTIONS_TOPIC,
                            value=record)
            producer.flush()
            _id += 1
            time.sleep(DELAY)
    except KeyboardInterrupt: print("Stopped")
    finally:
        producer.flush()
# Out:
# produce message
# b'{"id": 0, "data": [[-0.044, 2.454]], "current_time": "2025-10-27T09:04:39.650987"}'
# produce message
# b'{"id": 1, "data": [[-2.127, -2.041]], "current_time": "2025-10-27T09:04:42.685863"}'
# produce message
# b'{"id": 2, "data": [[-1.84, -1.954]], "current_time": "2025-10-27T09:04:45.430450"}'
# produce message
# b'{"id": 3, "data": [[-0.409, -2.916]], "current_time": "2025-10-27T09:04:47.462326"}'
# produce message
# b'{"id": 4, "data": [[-2.368, -1.702]], "current_time": "2025-10-27T09:04:49.497868"}'
# produce message
# b'{"id": 5, "data": [[3.938, -0.867]], "current_time": "2025-10-27T09:04:51.516150"}'
# produce message
# b'{"id": 6, "data": [[-2.28, -1.79]], "current_time": "2025-10-27T09:04:53.571008"}'
# produce message
# b'{"id": 7, "data": [[2.093, 2.935]], "current_time": "2025-10-27T09:04:55.599707"}'
# produce message
# b'{"id": 8, "data": [[-2.058, -1.861]], "current_time": "2025-10-27T09:04:57.632818"}'
# produce message
# b'{"id": 9, "data": [[-3.887, -2.682]], "current_time": "2025-10-27T09:04:59.648402"}'
# produce message
# b'{"id": 10, "data": [[-2.013, -2.021]], "current_time": "2025-10-27T09:05:01.660741"}'
# produce message
# b'{"id": 11, "data": [[2.019, 1.741]], "current_time": "2025-10-27T09:05:03.675058"}'
# produce message
# b'{"id": 12, "data": [[-1.913, 2.532]], "current_time": "2025-10-27T09:05:05.689409"}'
# produce message
# b'{"id": 13, "data": [[0.1, -0.168]], "current_time": "2025-10-27T09:05:07.722016"}'
# produce message
# b'{"id": 14, "data": [[1.982, 2.029]], "current_time": "2025-10-27T09:05:09.763183"}'
# produce message
# b'{"id": 15, "data": [[0.384, -2.374]], "current_time": "2025-10-27T09:05:11.870614"}'
# produce message
# b'{"id": 16, "data": [[-1.992, -1.865]], "current_time": "2025-10-27T09:05:14.031177"}'
# produce message
# b'{"id": 17, "data": [[1.874, 2.221]], "current_time": "2025-10-27T09:05:16.076403"}'
# produce message
# b'{"id": 18, "data": [[-1.753, -2.34]], "current_time": "2025-10-27T09:05:18.164560"}'
# produce message
# b'{"id": 19, "data": [[1.483, 1.3]], "current_time": "2025-10-27T09:05:20.172479"}'
# produce message
# b'{"id": 20, "data": [[-1.734, -2.158]], "current_time": "2025-10-27T09:05:22.192767"}'
# produce message
# b'{"id": 21, "data": [[1.742, 1.984]], "current_time": "2025-10-27T09:05:24.219063"}'
# produce message
# b'{"id": 22, "data": [[0.9, -1.499]], "current_time": "2025-10-27T09:05:26.230357"}'
# produce message
# b'{"id": 23, "data": [[0.711, -3.137]], "current_time": "2025-10-27T09:05:28.245095"}'
# produce message
# b'{"id": 24, "data": [[-2.52, -2.325]], "current_time": "2025-10-27T09:05:30.255587"}'
# produce message
# b'{"id": 25, "data": [[-1.964, -2.37]], "current_time": "2025-10-27T09:05:32.269137"}'
# produce message
# b'{"id": 26, "data": [[-1.989, -1.843]], "current_time": "2025-10-27T09:05:34.279098"}'
# produce message
# b'{"id": 27, "data": [[1.525, 2.259]], "current_time": "2025-10-27T09:05:36.291654"}'
# produce message
# b'{"id": 28, "data": [[-3.369, 3.56]], "current_time": "2025-10-27T09:05:38.299162"}'
# produce message
# b'{"id": 29, "data": [[2.117, 1.647]], "current_time": "2025-10-27T09:05:40.312286"}'
# produce message
# b'{"id": 30, "data": [[2.045, 2.233]], "current_time": "2025-10-27T09:05:42.322830"}'
# produce message
# b'{"id": 31, "data": [[-2.028, -1.77]], "current_time": "2025-10-27T09:05:44.334321"}'
# produce message
# b'{"id": 32, "data": [[-1.876, -2.076]], "current_time": "2025-10-27T09:05:46.342269"}'
# produce message
# b'{"id": 33, "data": [[-2.074, -2.041]], "current_time": "2025-10-27T09:05:48.354212"}'
# produce message
# b'{"id": 34, "data": [[1.808, 1.565]], "current_time": "2025-10-27T09:05:50.364068"}'
# produce message
# b'{"id": 35, "data": [[-2.759, -2.427]], "current_time": "2025-10-27T09:05:52.371008"}'
# produce message
# b'{"id": 36, "data": [[2.069, -2.324]], "current_time": "2025-10-27T09:05:54.381724"}'
# produce message
# b'{"id": 37, "data": [[-2.183, -1.815]], "current_time": "2025-10-27T09:05:56.392830"}'
# produce message
# b'{"id": 38, "data": [[1.599, 2.061]], "current_time": "2025-10-27T09:05:58.401285"}'
# produce message
# b'{"id": 39, "data": [[-2.262, -1.966]], "current_time": "2025-10-27T09:06:00.448273"}'
# produce message
# b'{"id": 40, "data": [[1.914, 2.055]], "current_time": "2025-10-27T09:06:02.478347"}'
# produce message
# b'{"id": 41, "data": [[-1.8, -2.483]], "current_time": "2025-10-27T09:06:04.493616"}'
# produce message
# b'{"id": 42, "data": [[-2.734, -2.233]], "current_time": "2025-10-27T09:06:06.518437"}'
# produce message
# b'{"id": 43, "data": [[-1.703, -0.973]], "current_time": "2025-10-27T09:06:08.530669"}'
# produce message
# b'{"id": 44, "data": [[-2.32, -1.977]], "current_time": "2025-10-27T09:06:10.547704"}'
# produce message
# b'{"id": 45, "data": [[1.708, 1.894]], "current_time": "2025-10-27T09:06:12.557941"}'
# produce message
# b'{"id": 46, "data": [[2.186, 1.81]], "current_time": "2025-10-27T09:06:14.567821"}'
# produce message
# b'{"id": 47, "data": [[-1.956, -2.185]], "current_time": "2025-10-27T09:06:16.577590"}'
# produce message
# b'{"id": 48, "data": [[-1.913, -2.294]], "current_time": "2025-10-27T09:06:18.589243"}'
# produce message
# b'{"id": 49, "data": [[-3.123, -1.783]], "current_time": "2025-10-27T09:06:20.600106"}'
# produce message
# b'{"id": 50, "data": [[-1.228, -1.841]], "current_time": "2025-10-27T09:06:22.721609"}'
# produce message
# b'{"id": 51, "data": [[-1.661, -2.556]], "current_time": "2025-10-27T09:06:24.739410"}'
# produce message
# b'{"id": 52, "data": [[2.356, 1.966]], "current_time": "2025-10-27T09:06:26.783787"}'
# produce message
# b'{"id": 53, "data": [[1.906, 2.99]], "current_time": "2025-10-27T09:06:28.805888"}'
# produce message
# b'{"id": 54, "data": [[-2.139, -2.23]], "current_time": "2025-10-27T09:06:30.830037"}'
# produce message
# b'{"id": 55, "data": [[2.53, 2.326]], "current_time": "2025-10-27T09:06:32.898546"}'
# produce message
# b'{"id": 56, "data": [[-2.418, -1.868]], "current_time": "2025-10-27T09:06:34.908273"}'
# produce message
# b'{"id": 57, "data": [[1.987, 2.42]], "current_time": "2025-10-27T09:06:36.924229"}'
# produce message
# b'{"id": 58, "data": [[2.006, 1.33]], "current_time": "2025-10-27T09:06:38.937639"}'
# produce message
# b'{"id": 59, "data": [[-2.234, -2.185]], "current_time": "2025-10-27T09:06:40.971636"}'
# produce message
# b'{"id": 60, "data": [[-1.845, -1.7]], "current_time": "2025-10-27T09:06:43.005510"}'
# produce message
# b'{"id": 61, "data": [[2.2, 1.989]], "current_time": "2025-10-27T09:06:45.016018"}'
# produce message
# b'{"id": 62, "data": [[-1.68, -0.923]], "current_time": "2025-10-27T09:06:47.025821"}'
# produce message
# b'{"id": 63, "data": [[1.636, 2.086]], "current_time": "2025-10-27T09:06:49.041092"}'
# produce message
# b'{"id": 64, "data": [[-2.33, -2.576]], "current_time": "2025-10-27T09:06:51.054186"}'
# produce message
# b'{"id": 65, "data": [[-1.897, -2.12]], "current_time": "2025-10-27T09:06:53.066936"}'
# produce message
# b'{"id": 66, "data": [[2.063, 1.755]], "current_time": "2025-10-27T09:06:55.079019"}'
# produce message
# b'{"id": 67, "data": [[2.273, 2.222]], "current_time": "2025-10-27T09:06:57.100251"}'
# produce message
# b'{"id": 68, "data": [[-2.17, -2.485]], "current_time": "2025-10-27T09:06:59.256384"}'
# produce message
# b'{"id": 69, "data": [[-2.295, -2.013]], "current_time": "2025-10-27T09:07:01.341373"}'
# produce message
# b'{"id": 70, "data": [[-1.729, -1.944]], "current_time": "2025-10-27T09:07:03.352865"}'
# Stopped
