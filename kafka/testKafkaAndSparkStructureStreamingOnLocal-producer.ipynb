# %%
from kafka import KafkaProducer
from json import dumps
from time import sleep
topic_name = "LeNguyenHoangPhuc_RandomNumber"
kafka_server = "localhost:9092"

producer = KafkaProducer(bootstrap_servers = kafka_server, value_serializer = lambda x:dumps(x).encode("utf-8"))

for e in range(1000):
    data = {'number' : e}
    producer.send(topic_name, value=data)
    print(str(data) + "sent")
    sleep(5)

producer.flush()
# Out:
# {'number': 0}sent
# {'number': 1}sent
# {'number': 2}sent
# {'number': 3}sent
# {'number': 4}sent
# {'number': 5}sent
# {'number': 6}sent
# {'number': 7}sent
# {'number': 8}sent
# {'number': 9}sent
# {'number': 10}sent
# {'number': 11}sent
# {'number': 12}sent
# {'number': 13}sent
# {'number': 14}sent
# {'number': 15}sent
# {'number': 16}sent
# {'number': 17}sent
# {'number': 18}sent
# {'number': 19}sent
# {'number': 20}sent
# {'number': 21}sent
# {'number': 22}sent
# {'number': 23}sent
# {'number': 24}sent
# {'number': 25}sent
# {'number': 26}sent
# {'number': 27}sent
# {'number': 28}sent
# {'number': 29}sent
# {'number': 30}sent
# {'number': 31}sent
# {'number': 32}sent
# {'number': 33}sent
# {'number': 34}sent
# {'number': 35}sent
# {'number': 36}sent
# {'number': 37}sent
# {'number': 38}sent
# {'number': 39}sent
# {'number': 40}sent
# {'number': 41}sent
# {'number': 42}sent
# {'number': 43}sent
# {'number': 44}sent
# {'number': 45}sent
# {'number': 46}sent
# {'number': 47}sent
# {'number': 48}sent
# {'number': 49}sent
# {'number': 50}sent
# {'number': 51}sent
# {'number': 52}sent
# {'number': 53}sent
# {'number': 54}sent
# {'number': 55}sent
# {'number': 56}sent
# {'number': 57}sent
# {'number': 58}sent
# {'number': 59}sent
# {'number': 60}sent
# {'number': 61}sent
# {'number': 62}sent
# {'number': 63}sent
# {'number': 64}sent
# {'number': 65}sent
# {'number': 66}sent
# {'number': 67}sent
# {'number': 68}sent
# {'number': 69}sent
# {'number': 70}sent
# {'number': 71}sent
# {'number': 72}sent
# {'number': 73}sent
# {'number': 74}sent
# {'number': 75}sent
# {'number': 76}sent
# {'number': 77}sent
# {'number': 78}sent
# {'number': 79}sent
# {'number': 80}sent
# {'number': 81}sent
# {'number': 82}sent
# {'number': 83}sent
# {'number': 84}sent
# {'number': 85}sent
# {'number': 86}sent
# {'number': 87}sent
# {'number': 88}sent
# {'number': 89}sent
# {'number': 90}sent
# {'number': 91}sent
# {'number': 92}sent
# {'number': 93}sent
# {'number': 94}sent
# {'number': 95}sent
# {'number': 96}sent
# {'number': 97}sent
# {'number': 98}sent
# {'number': 99}sent
# {'number': 100}sent
# {'number': 101}sent
# {'number': 102}sent
# {'number': 103}sent
# {'number': 104}sent
# {'number': 105}sent
# {'number': 106}sent
# {'number': 107}sent
# {'number': 108}sent
# {'number': 109}sent
# {'number': 110}sent
# {'number': 111}sent
# {'number': 112}sent
# {'number': 113}sent
# {'number': 114}sent
# {'number': 115}sent
# {'number': 116}sent
# {'number': 117}sent
# {'number': 118}sent
# {'number': 119}sent
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 13
#      11     producer.send(topic_name, value=data)
#      12     print(str(data) + "sent")
# ---> 13     sleep(5)
#      15 producer.flush()
#
# KeyboardInterrupt:
